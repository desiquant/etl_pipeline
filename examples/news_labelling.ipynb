# %%
from news_ml.company import extract_company_from_article_openai

await extract_company_from_article_openai(
    "Target: ₹2,550 CMP: ₹1782.30 Given HDFC Bank’s low-CASA, mortgage-heavy post-merger balance sheet, the understandable reflex is to see rate cuts as a serious headwind for HDFCB. In reality, expiry benefits of legacy high-cost NCDs/FDs inherited from the parent balance sheet; immediate benefits of rate cuts on short-term borrowings (10 per cent of NDTL); and a likely CASA revival from monetary/liquidity easing – bode well for FY26 RoA outlook of our top pick within the banking space. Rate cuts are actually a medium-term positive for banks; HDFCB has unique tailwinds Most of the street sees rate cuts as a pressure point on bank margins. In ‘Rate cuts – a belated gentle tailwind’, we demonstrate two things. First, for our coverage private banks, the margin impact of rate cut (already built into estimates) is not terribly high (2HFY25 earnings slower by 3-6 per cent than they would be otherwise). Second, an easing cycle comes with delayed benefits of FD repricing, increased CASA momentum or likely loan mix shift. HDFC Bank specifically has the additional tailwinds of expiries of higher-cost NCD and FDs that it inherited from its parent entity, in its margin journey. We address the CDR/LCR concerns raised about HDFCB’s growth outlook and substantiate our prognosis of ‘growth-as-usual’ from FY26 onwards."
)

# %%
from news_ml.company import match_closest_listed_company

await match_closest_listed_company("AG Tech")

# %% [markdown]
# # \_CAN_DELETE_LATER\_

# %%
import pandas as pd

pd.read_parquet("../data/s3/news.parquet")
# Out:
#                                             article_text  \
# 0      Three terrorists were shot dead in an overnigh...
# 1      The door-to-door canvassing has returned to th...
# 2      A day after India’s External Affairs Minister ...
# 3      The main dome of the Taj Mahal here witnessed ...
# 4      In the wake of an undiagnosed fever claiming 1...
# ...                                                  ...
# 19085                                               None
# 19086                                               None
# 19087  The Nepalese conglomerate CG Corp Global is pl...
# 19088  The Nifty 50 remained volatile for another ses...
# 19089                                               None
#
#                      author              date_modified  \
# 0                  FP Staff  2024-09-14T09:50:21+05:30
# 1                  FP Staff  2024-09-14T11:30:04+05:30
# 2                  FP Staff  2024-09-14T11:08:44+05:30
# 3      press trust of india  2024-09-14T11:39:44+05:30
# 4      press trust of india  2024-09-14T12:58:12+05:30
# ...                     ...                        ...
# 19085                  None  2024-09-17T15:49:16+05:30
# 19086     Sucheta Anchaliya  2024-09-17T14:10:12+05:30
# 19087             Bloomberg  2024-09-18T16:49:07+05:30
# 19088  Sunil Shankar Matkar  2024-09-18T16:54:33+05:30
# 19089                  None  2024-09-18T17:19:27+05:30
#
#                   date_published  \
# 0      2024-09-14T09:49:50+05:30
# 1      2024-09-14T11:30:04+05:30
# 2      2024-09-14T11:08:02+05:30
# 3      2024-09-14T11:39:35+05:30
# 4      2024-09-14T12:58:12+05:30
# ...                          ...
# 19085  2024-09-17T07:25:13+05:30
# 19086  2024-09-17T13:29:18+05:30
# 19087  2024-09-18T16:49:07+05:30
# 19088  2024-09-18T16:54:33+05:30
# 19089  2024-09-18T17:15:46+05:30
#
#                                              description  \
# 0      The encounter between security forces and terr...
# 1      But as the assembly election returns to Jammu ...
# 2      Chinese Foreign Ministry spokesperson Mao Ning...
# 3      A senior official of the Archaeological Survey...
# 4      Following an undiagnosed fever outbreak that h...
# ...                                                  ...
# 19085  Sensex Today | Stock Market LIVE Updates: Amon...
# 19086  Merchant bankers attribute the higher fee to t...
# 19087  The Kathmandu-based group will use the pre-IPO...
# 19088  The weekly options data indicated that 25,500 ...
# 19089  US Fed Meeting Live Updates: The last time the...
#
#                 scrapy_parsed_at         scrapy_scraped_at  \
# 0     2024-09-16 14:34:52.026911 2024-09-16 14:34:51+00:00
# 1     2024-09-16 14:34:52.112643 2024-09-16 14:34:51+00:00
# 2     2024-09-16 14:34:52.122909 2024-09-16 14:34:51+00:00
# 3     2024-09-16 14:34:52.176630 2024-09-16 14:34:51+00:00
# 4     2024-09-16 14:34:52.350913 2024-09-16 14:34:51+00:00
# ...                          ...                       ...
# 19085 2024-09-18 11:15:22.546572 2024-09-18 11:15:22+00:00
# 19086 2024-09-18 11:15:22.950114 2024-09-18 11:15:22+00:00
# 19087 2024-09-18 11:31:10.513461 2024-09-18 11:31:09+00:00
# 19088 2024-09-18 11:31:11.104063 2024-09-18 11:31:10+00:00
# 19089 2024-09-18 11:54:20.277003 2024-09-18 11:54:19+00:00
#
#                                                    title  \
# 0      3 terrorists shot dead in J&K's Baramulla; ope...
# 1      A new era in J&K politics: Candidate door-to-d...
# 2      China says troops disengaged in 4 places, incl...
# 3      Rainwater leaks from Taj Mahal's dome due to i...
# 4      India sets up surveillance after undiagnosed f...
# ...                                                  ...
# 19085  Closing Bell | Sensex up 90 pts, Nifty ends ab...
# 19086  Merchant bankers charge much more to manage IP...
# 19087  Maker of instant noodle brand Wai Wai plans pr...
# 19088  Technical View: Breaching 25,500 crucial for f...
# 19089  US Fed Meeting Live Updates: Powell to announc...
#
#                                                      url
# 0      https://www.firstpost.com/india/jammu-and-kash...
# 1      https://www.firstpost.com/india/a-new-era-in-j...
# 2      https://www.firstpost.com/india/china-says-tro...
# 3      https://www.firstpost.com/india/rainwater-leak...
# 4      https://www.firstpost.com/india/india-sets-up-...
# ...                                                  ...
# 19085  https://www.moneycontrol.com/news/business/mar...
# 19086  https://www.moneycontrol.com/news/business/mar...
# 19087  https://www.moneycontrol.com/news/business/mar...
# 19088  https://www.moneycontrol.com/news/business/mar...
# 19089  https://www.moneycontrol.com/news/business/mar...
#
# [19090 rows x 9 columns]

# %%
import asyncio

import pandas as pd
from prefect import flow, task


@task(log_prints=True)
def get_unlabelled_news_task(
    df_news: pd.DataFrame, df_news_l: pd.DataFrame
) -> pd.DataFrame:
    """
    Get the news articles that are unlabelled, by taking the difference between existing articles and already labelled articles

    Parameters:
        - df_news: dataframe of news articles
        - df_news_l: dataframe of news articles with labels
    """

    # get unlabelled articles
    df_news_ul = pd.merge(
        df_news, df_news_l[["url"]], on="url", how="left", indicator=True
    )
    df_news_ul = df_news_ul[df_news_ul["_merge"] == "left_only"]
    df_news_ul = df_news_ul.drop(columns=["_merge"])

    # restrict: properly formatted articles
    df_news_ul = df_news_ul[~df_news_ul["article_text"].isna()]

    print("Total unlabelled articles:", df_news_ul.shape[0])

    # restrict: articles since start of month
    df_news_ul = df_news_ul[
        df_news_ul[["date_modified", "date_published"]].max(axis=1)
        >= pd.Timestamp.today() - pd.offsets.MonthBegin(2)
    ]

    # restrict: max 1000 articles to label
    df_news_ul = df_news_ul[:1000]

    return df_news_ul


@task(log_prints=True)
async def label_news_task(df_news_ul: pd.DataFrame) -> pd.DataFrame:
    """
    Given a list of news articles, labels then

    Parameters:
        - df_news_ul - dataframe of news articles without labels

    """

    from news_ml.company import label

    df_news_l = await label(
        df=df_news_ul,
        concurrency=10,
        sample_run=True,
    )

    print("Total newly labelled articles:", df_news_l.shape[0])

    return df_news_l


NEWS_URIS = ["../data/s3/news.parquet", "s3://arthanex/data/news.parquet"]
NEWS_LABELLED_URIS = [
    "../data/s3/news_labelled.parquet",
    "s3://arthanex/data/news_labelled.parquet",
]


@task(log_prints=True)
def download_data():
    import os

    df = pd.read_parquet(NEWS_URIS[0 if os.path.isfile(NEWS_URIS[0]) else 1])
    # df = pd.read_parquet("../cache/news.parquet")

    # parse the date columns
    # TODO: this must be done when the parquet file is generated so that all the columns have the correct schema.
    for c in ["date_modified", "date_published"]:
        df[c] = (
            pd.to_datetime(df[c], format="mixed", errors="coerce", utc=True)
            .dt.tz_convert("Asia/Kolkata")
            .dt.tz_localize(None)
        )

    df = df.sort_values(by=["date_modified", "date_published"], ascending=False)

    try:
        df_l = pd.read_parquet(
            NEWS_LABELLED_URIS[0 if os.path.isfile(NEWS_LABELLED_URIS[0]) else 1]
        )
    except FileNotFoundError:
        df_l = pd.DataFrame(columns=["url"])

    return (df, df_l)


@flow(log_prints=True)
async def label_news_flow():
    """
    News article labelling flows that does the following:
        - Downloads news articles and the labelled dataset from S3
        - Labels the unlabelled news articles
        - Save the result to S3
    """

    df, df_l = download_data()

    # latest unlabeled-only news
    df_ul = get_unlabelled_news_task(df, df_l)

    # label latest unlabelled-only news
    df_l_new = await label_news_task(df_ul)

    # merge labelled news with existing news
    df_l = pd.concat([df_l, df_l_new], ignore_index=True)

    print("Total labelled articles:", df_l.shape[0])

    # save labelled news articles to local, s3
    df_l.to_parquet(NEWS_LABELLED_URIS[0])
    df_l.to_parquet(NEWS_LABELLED_URIS[1])

    print("Uploaded labelled dataset to S3")


await label_news_flow()

# if __name__ == "__main__":
#     asyncio.run(label_news_flow())
# label_news_flow.serve(name="news-article-label")
# Out:
# 17:56:02.407 | INFO    | prefect.engine - Created flow run 'illustrious-cockatoo' for flow 'label-news-flow'
# 17:56:02.408 | INFO    | prefect.engine - View at http://127.0.0.1:4200/runs/flow-run/e5eb7eda-913f-4998-a284-63ba67a7a9c3
# 27       Broker’s Call: Narayana Hrudayalaya (Reduce)
# 28  Taking Stock: Nifty, Sensex slip from record h...
# 29  Heritage Foods Share Price Off Day's Low On Bo...
#
#                                        _topic_company  \
# 0                                             Samsung
# 1                      Tata Consultancy Services Ltd.
# 2                                                 L&T
# 3                           Tata Consultancy Services
# 4                                     HDFC Securities
# 5                           State Bank of India (SBI)
# 6                                       Quality Power
# 7                                      CG Corp Global
# 8                        Bharatiya Janata Party (BJP)
# 9                                          BSE Sensex
# 10                             Heritage Foods Limited
# 11                                              Wipro
# 12  The company name with the highest probability ...
# 13                              Bajaj Housing Finance
# 14                              Manba Finance Limited
# 15                                          Tata Sons
# 16                                   Aurobindo Pharma
# 17                             Shelter Pharma Limited
# 18                                State Bank of India
# 19                                 Zydus Lifesciences
# 20                                 Zydus Lifesciences
# 21                                 US Federal Reserve
# 22                       Nutrient Based Subsidy (NBS)
# 23                               JK Tyre & Industries
# 24                      HDFC Asset Management Company
# 25                                              India
# 26                                      Lupin Limited
# 27                               Narayana Hrudayalaya
# 28                                         ICICI Bank
# 29                                Heritage Foods Ltd.
#
#                                      _listed_company
# 0                [TVS Electronics Limited, TVSELECT]
# 1           [Tata Consultancy Services Limited, TCS]
# 2            [L&T Technology Services Limited, LTTS]
# 3           [Tata Consultancy Services Limited, TCS]
# 4                      [HDFC Bank Limited, HDFCBANK]
# 5                        [State Bank of India, SBIN]
# 6                   [Reliance Power Limited, RPOWER]
# 7                   [Global Surfaces Limited, GSLSU]
# 8                    [Bata India Limited, BATAINDIA]
# 9                                 [BSE Limited, BSE]
# 10              [Heritage Foods Limited, HERITGFOOD]
# 11                            [Wipro Limited, WIPRO]
# 12      [Elecon Engineering Company Limited, ELECON]
# 13               [Bajaj Finance Limited, BAJFINANCE]
# 14          [Manappuram Finance Limited, MANAPPURAM]
# 15           [Tata Communications Limited, TATACOMM]
# 16            [Aurobindo Pharma Limited, AUROPHARMA]
# 17                     [Gland Pharma Limited, GLAND]
# 18                       [State Bank of India, SBIN]
# 19           [Zydus Lifesciences Limited, ZYDUSLIFE]
# 20           [Zydus Lifesciences Limited, ZYDUSLIFE]
# 21           [The Federal Bank  Limited, FEDERALBNK]
# 22                          [Subros Limited, SUBROS]
# 23            [JK Tyre & Industries Limited, JKTYRE]
# 24  [HDFC Asset Management Company Limited, HDFCAMC]
# 25                       [3M India Limited, 3MINDIA]
# 26                            [Lupin Limited, LUPIN]
# 27                   [Narayana Hrudayalaya Ltd., NH]
# 28                   [ICICI Bank Limited, ICICIBANK]
# 29              [Heritage Foods Limited, HERITGFOOD]
# 17:56:05.576 | INFO    | Flow run 'illustrious-cockatoo' - Total labelled articles: 30
# 17:56:06.095 | INFO    | Flow run 'illustrious-cockatoo' - Uploaded labelled dataset to S3
# 17:56:06.137 | INFO    | Flow run 'illustrious-cockatoo' - Finished in state Completed()
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
